# %%
sourcedir = '/Volumes/incremental_load_2/default/orders_data/source/'
targetdir = '/Volumes/incremental_load_2/default/orders_data/archive/'
stage_table = '/Volumes/incremental_load_2/default/orders_data'

# %%
df = spark.read.csv(sourcedir, header=True, inferSchema=True)

# %%
df.write.format('delta').mode('overwrite').saveAsTable('orders_data_stage')

# %%
# list all file in the source
files =dbutils.fs.ls(sourcedir)

# Iterate of the list one by one and print each file separately
for file in files:
    src_path = file.path
# construct the target path
target_path = targetdir + src_path.split('/')[-1]

# move the file from source to target
dbutils.fs.mv(src_path, target_path)
